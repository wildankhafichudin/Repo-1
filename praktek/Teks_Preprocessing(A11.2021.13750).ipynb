# %%
pip install nltk
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\ASUS\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting matplotlib
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.1/7.6 MB 273.1 kB/s eta 0:00:28
# ...

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
pip install Sastrawi
# Out:
# ...
#                                               0.0/209.7 kB ? eta -:--:--
#      -----                                    30.7/209.7 kB ? eta -:--:--
#      -----                                    30.7/209.7 kB ? eta -:--:--
#      -----                                    30.7/209.7 kB ? eta -:--:--
#      -----                                    30.7/209.7 kB ? eta -:--:--
#      -----                                    30.7/209.7 kB ? eta -:--:--
#      -------------------                  112.6/209.7 kB 504.4 kB/s eta 0:00:01
#      -------------------                  112.6/209.7 kB 504.4 kB/s eta 0:00:01
#      -------------------                  112.6/209.7 kB 504.4 kB/s eta 0:00:01
#      ---------------------                122.9/209.7 kB 328.4 kB/s eta 0:00:01
#      ---------------------                122.9/209.7 kB 328.4 kB/s eta 0:00:01
#      ---------------------                122.9/209.7 kB 328.4 kB/s eta 0:00:01
# ...

# %% [markdown]
# # 1. Lowercase #
#
# Lowercase digunakan untuk merubah format teks menjadi format huruf kecil semua.

# %%
kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
lowercase = kalimat.lower()
print(lowercase)

#lower() merupakan method untuk merubah kalimat yang awalnya huruf besar lalu dirubah menjadi huruf kecil
# Out:
# jalan mh thamrin malam ini dipadati pengunjung dan pedagang. di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan ok-oce yang berjajar di jalanannya. pantauan detikcom di lokasi, jalan mh thamrin, jakarta pusat, minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika ambon, dan sebagainya. di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di indonesia, seperti nusa tenggara, sumatera utara, kalimantan selatan, riau, sulawesi barat, dan lain-lain. stan tersebut merupakan binaan ok oce, dan terdiri dari 14 stan. salah satunya stan provinsi yang berisi makanan. namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. seperti bir pletok hj amilati yang dijual di stan provinsi maluku. minuman
# ...

# %% [markdown]
# # 2. Removing Numbers #
# Menghilangkan karakter angka yang ada pada dokumen

# %%
import re

kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
hasil = re.sub(r"\d+", "", kalimat)
hasil
# Out:
# 'Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (//), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari  stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Bet
# ...

# %% [markdown]
# # 3. Removing Punctuation #
# Digunakan untuk menghapus tanda baca

# %%
import string

kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
hasil = kalimat.translate(str.maketrans("","",string.punctuation))
hasil
# Out:
# 'Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang Di antara pedagang yang berjajar mengais rezeki di malam tahun baru ada stan OKOCE yang berjajar di jalanannya Pantauan detikcom di lokasi Jalan MH Thamrin Jakarta Pusat Minggu 31122017 stanstan diketahui sudah ada sejak sore tadi Bertenda putih ada ratusan pedagang berderet menjajakan dagangan di dalamnya yang seluruhnya adalah kuliner Ada pempek sosis bakar kerak telor toge goreng asinan buah asinan sayur bika Ambon dan sebagainya Di stan ini ada nomor dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia seperti Nusa Tenggara Sumatera Utara Kalimantan Selatan Riau Sulawesi Barat dan lainlain Stan tersebut merupakan binaan OK OCE dan terdiri dari 14 stan Salah satunya stan Provinsi yang berisi makanan Namun tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku Minuman khas Betawi ini terpaksa dijual di sta
# ...

# %% [markdown]
# # 4. Removing Whitespace #
# Digunakan untuk menghapus karakter kosong

# %%
kalimat = "         Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang."
hasil = kalimat.strip()
hasil
# Out:
# 'Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang.'

# %% [markdown]
# # 5. Separating Sentences with Split () Method #
# Fungsi `split()` memisahkan _string_ ke dalam _list_ dengan spasi sebagai pemisah jika tidak ditentukan pemisahnya.#

# %%
kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
pisah = kalimat.split()
pisah
# Out:
# ['Jalan',
#  'MH',
#  'Thamrin',
#  'malam',
#  'ini',
#  'dipadati',
#  'pengunjung',
#  'dan',
#  'pedagang.',
#  'Di',
#  'antara',
#  'pedagang',
#  'yang',
#  'berjajar',
#  'mengais',
#  'rezeki',
#  'di',
#  'malam',
#  'tahun',
#  'baru,',
#  'ada',
#  'stan',
#  'OK-OCE',
#  'yang',
#  'berjajar',
#  'di',
#  'jalanannya.',
#  'Pantauan',
#  'detikcom',
#  'di',
#  'lokasi,',
#  'Jalan',
#  'MH',
#  'Thamrin,',
#  'Jakarta',
#  'Pusat,',
#  'Minggu',
#  '(31/12/2017),',
#  'stan-stan',
#  'diketahui',
#  'sudah',
#  'ada',
#  'sejak',
#  'sore',
#  'tadi.',
#  'Bertenda',
#  'putih,',
#  'ada',
#  'ratusan',
#  'pedagang',
#  'berderet',
#  'menjajakan',
#  'dagangan',
#  'di',
#  'dalamnya,',
#  'yang',
#  'seluruhnya',
#  'adalah',
#  'kuliner.',
#  'Ada',
#  'pempek,',
#  'sosis',
#  'bakar,',
#  'kerak',
#  'telor,',
#  'toge',
#  'goreng,',
#  'asinan',
#  'buah,',
#  'asinan',
#  'sayur,',
#  'bika',
#  'Ambon,',
#  'dan',
#  'sebagainya.',
#  'Di',
#  'stan',
# ...

# %% [markdown]
# ## 6. Tokenizing: Word Tokenizing Using NLTK Module ##
# Menggunakan _library_ NLTK untuk memisahkan kata dalam sebuah kalimat.

# %%
import nltk
from nltk.tokenize import word_tokenize 

kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."

tokens = nltk.tokenize.word_tokenize(kalimat)
print(tokens)
# Out:
# ['Jalan', 'MH', 'Thamrin', 'malam', 'ini', 'dipadati', 'pengunjung', 'dan', 'pedagang', '.', 'Di', 'antara', 'pedagang', 'yang', 'berjajar', 'mengais', 'rezeki', 'di', 'malam', 'tahun', 'baru', ',', 'ada', 'stan', 'OK-OCE', 'yang', 'berjajar', 'di', 'jalanannya', '.', 'Pantauan', 'detikcom', 'di', 'lokasi', ',', 'Jalan', 'MH', 'Thamrin', ',', 'Jakarta', 'Pusat', ',', 'Minggu', '(', '31/12/2017', ')', ',', 'stan-stan', 'diketahui', 'sudah', 'ada', 'sejak', 'sore', 'tadi', '.', 'Bertenda', 'putih', ',', 'ada', 'ratusan', 'pedagang', 'berderet', 'menjajakan', 'dagangan', 'di', 'dalamnya', ',', 'yang', 'seluruhnya', 'adalah', 'kuliner', '.', 'Ada', 'pempek', ',', 'sosis', 'bakar', ',', 'kerak', 'telor', ',', 'toge', 'goreng', ',', 'asinan', 'buah', ',', 'asinan', 'sayur', ',', 'bika', 'Ambon', ',', 'dan', 'sebagainya', '.', 'Di', 'stan', 'ini', 'ada', 'nomor', ',', 'dan', 'beberapa', 'di', 'antaranya', 'dibubuhi', 'identitas', 'kuliner', 'provinsi', 'di', 'Indonesia', ',', 'seperti', 'Nu
# ...

# %%
tokens
# Out:
# ['Jalan',
#  'MH',
#  'Thamrin',
#  'malam',
#  'ini',
#  'dipadati',
#  'pengunjung',
#  'dan',
#  'pedagang',
#  '.',
#  'Di',
#  'antara',
#  'pedagang',
#  'yang',
#  'berjajar',
#  'mengais',
#  'rezeki',
#  'di',
#  'malam',
#  'tahun',
#  'baru',
#  ',',
#  'ada',
#  'stan',
#  'OK-OCE',
#  'yang',
#  'berjajar',
#  'di',
#  'jalanannya',
#  '.',
#  'Pantauan',
#  'detikcom',
#  'di',
#  'lokasi',
#  ',',
#  'Jalan',
#  'MH',
#  'Thamrin',
#  ',',
#  'Jakarta',
#  'Pusat',
#  ',',
#  'Minggu',
#  '(',
#  '31/12/2017',
#  ')',
#  ',',
#  'stan-stan',
#  'diketahui',
#  'sudah',
#  'ada',
#  'sejak',
#  'sore',
#  'tadi',
#  '.',
#  'Bertenda',
#  'putih',
#  ',',
#  'ada',
#  'ratusan',
#  'pedagang',
#  'berderet',
#  'menjajakan',
#  'dagangan',
#  'di',
#  'dalamnya',
#  ',',
#  'yang',
#  'seluruhnya',
#  'adalah',
#  'kuliner',
#  '.',
#  'Ada',
#  'pempek',
#  ',',
#  'sosis',
#  'bakar',
#  ',',
#  'kerak',
#  'telor',
#  ',',
#  'toge',
#  'goreng',
#  ',',
# ...

# %% [markdown]
# ## 7. Tokenizing with Case Folding ##
# Menggabungkan teknik _Case Foling_ dengan _Tokenizing_.

# %%
from nltk.tokenize import word_tokenize 
 
kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
kalimat = kalimat.translate(str.maketrans('','',string.punctuation)).lower()

tokens = nltk.tokenize.word_tokenize(kalimat)

tokens
# Out:
# ['jalan',
#  'mh',
#  'thamrin',
#  'malam',
#  'ini',
#  'dipadati',
#  'pengunjung',
#  'dan',
#  'pedagang',
#  'di',
#  'antara',
#  'pedagang',
#  'yang',
#  'berjajar',
#  'mengais',
#  'rezeki',
#  'di',
#  'malam',
#  'tahun',
#  'baru',
#  'ada',
#  'stan',
#  'okoce',
#  'yang',
#  'berjajar',
#  'di',
#  'jalanannya',
#  'pantauan',
#  'detikcom',
#  'di',
#  'lokasi',
#  'jalan',
#  'mh',
#  'thamrin',
#  'jakarta',
#  'pusat',
#  'minggu',
#  '31122017',
#  'stanstan',
#  'diketahui',
#  'sudah',
#  'ada',
#  'sejak',
#  'sore',
#  'tadi',
#  'bertenda',
#  'putih',
#  'ada',
#  'ratusan',
#  'pedagang',
#  'berderet',
#  'menjajakan',
#  'dagangan',
#  'di',
#  'dalamnya',
#  'yang',
#  'seluruhnya',
#  'adalah',
#  'kuliner',
#  'ada',
#  'pempek',
#  'sosis',
#  'bakar',
#  'kerak',
#  'telor',
#  'toge',
#  'goreng',
#  'asinan',
#  'buah',
#  'asinan',
#  'sayur',
#  'bika',
#  'ambon',
#  'dan',
#  'sebagainya',
#  'di',
#  'stan',
#  'ini',
#  'ada',
#  'nomor',
# ...

# %% [markdown]
# ## 8. Frequency Distribution ##
# Menghitung frekuensi kemunculan setiap tokens(kata) dalam teks.

# %%
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
kalimat = kalimat.translate(str.maketrans('','',string.punctuation)).lower()

tokens = nltk.tokenize.word_tokenize(kalimat)
kemunculan = nltk.FreqDist(tokens)

print(kemunculan.most_common())
# Out:
# [('di', 13), ('stan', 11), ('yang', 10), ('ini', 8), ('ada', 8), ('dan', 6), ('sudah', 6), ('dari', 5), ('pedagang', 4), ('kuliner', 4), ('provinsi', 4), ('ok', 4), ('oce', 4), ('saya', 4), ('jalan', 3), ('mh', 3), ('thamrin', 3), ('jakarta', 3), ('seperti', 3), ('sulawesi', 3), ('namun', 3), ('dijual', 3), ('amilati', 3), ('mengaku', 3), ('acara', 3), ('malam', 2), ('pengunjung', 2), ('berjajar', 2), ('lokasi', 2), ('sejak', 2), ('sore', 2), ('tadi', 2), ('ratusan', 2), ('asinan', 2), ('identitas', 2), ('tenggara', 2), ('barat', 2), ('makanan', 2), ('tidak', 2), ('maluku', 2), ('kebagian', 2), ('dki', 2), ('jadi', 2), ('coach', 2), ('wirausaha', 2), ('ucap', 2), ('tebet', 2), ('pemprov', 2), ('untuk', 2), ('kita', 2), ('tapi', 2), ('belum', 2), ('rp', 2), ('50', 2), ('hingga', 2), ('kini', 2), ('harapan', 2), ('ya', 2), ('masih', 2), ('dipadati', 1), ('antara', 1), ('mengais', 1), ('rezeki', 1), ('tahun', 1), ('baru', 1), ('okoce', 1), ('jalanannya', 1), ('pantauan', 1), ('detikcom'
# ...

# %% [markdown]
# ## 9. Frequency Distribution Visualization with Matplotlib ##
# Untuk menggambarkan frekuensi kemunculan setiap tokens dapat menggunakan _library_ __matplotlib__ pada Python.
#
# https://matplotlib.org

# %%
import matplotlib.pyplot as plt

kemunculan.plot(30, cumulative=False)

plt.show()

# %% [markdown]
# ## 10. Tokenizing: Sentences Tokenizing Using NLTK Module ##
# Memisahkan kalimat dalam sebuah paragraf.

# %%
from nltk.tokenize import sent_tokenize

kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."

tokens = nltk.tokenize.sent_tokenize(kalimat)

print(tokens)
# Out:
# ['Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang.', 'Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya.', 'Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi.', 'Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner.', 'Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya.', 'Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain.', 'Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan.', 'Salah satunya stan Provinsi yang berisi makanan.', 'Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi.', 'Seperti Bir Pletok Hj Amilati yang dijual di 
# ...

# %% [markdown]
# ## 11. Filtering using NLTK ##

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
 
kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
kalimat = kalimat.translate(str.maketrans('','',string.punctuation)).lower()

tokens = word_tokenize(kalimat)
listStopword = set(stopwords.words('Indonesian'))

removed = []
for t in tokens:
    if t not in listStopword:
        removed.append(t)
 
print(removed)
# Out:
# ['jalan', 'mh', 'thamrin', 'malam', 'dipadati', 'pengunjung', 'pedagang', 'pedagang', 'berjajar', 'mengais', 'rezeki', 'malam', 'stan', 'okoce', 'berjajar', 'jalanannya', 'pantauan', 'detikcom', 'lokasi', 'jalan', 'mh', 'thamrin', 'jakarta', 'pusat', 'minggu', '31122017', 'stanstan', 'sore', 'bertenda', 'putih', 'ratusan', 'pedagang', 'berderet', 'menjajakan', 'dagangan', 'dalamnya', 'kuliner', 'pempek', 'sosis', 'bakar', 'kerak', 'telor', 'toge', 'goreng', 'asinan', 'buah', 'asinan', 'sayur', 'bika', 'ambon', 'stan', 'nomor', 'dibubuhi', 'identitas', 'kuliner', 'provinsi', 'indonesia', 'nusa', 'tenggara', 'sumatera', 'utara', 'kalimantan', 'selatan', 'riau', 'sulawesi', 'barat', 'lainlain', 'stan', 'binaan', 'ok', 'oce', '14', 'stan', 'salah', 'satunya', 'stan', 'provinsi', 'berisi', 'makanan', 'kuliner', 'dijual', 'stan', 'sesuai', 'identitas', 'nama', 'provinsi', 'bir', 'pletok', 'hj', 'amilati', 'dijual', 'stan', 'provinsi', 'maluku', 'minuman', 'khas', 'betawi', 'terpaksa', 'dij
# ...

# %% [markdown]
# ## 12. Filtering using Sastrawi: Stopword List ##
# Melihat daftar _stopword_ pada Sastrawi.

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nltk.tokenize import word_tokenize 

factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
kalimat = kalimat.translate(str.maketrans('','',string.punctuation)).lower()

stop = stopword.remove(kalimat)
tokens = nltk.tokenize.word_tokenize(stop)

print(tokens)
# Out:
# ['jalan', 'mh', 'thamrin', 'malam', 'dipadati', 'pengunjung', 'pedagang', 'antara', 'pedagang', 'berjajar', 'mengais', 'rezeki', 'malam', 'tahun', 'baru', 'stan', 'okoce', 'berjajar', 'jalanannya', 'pantauan', 'detikcom', 'lokasi', 'jalan', 'mh', 'thamrin', 'jakarta', 'pusat', 'minggu', '31122017', 'stanstan', 'diketahui', 'sejak', 'sore', 'tadi', 'bertenda', 'putih', 'ratusan', 'pedagang', 'berderet', 'menjajakan', 'dagangan', 'dalamnya', 'seluruhnya', 'kuliner', 'pempek', 'sosis', 'bakar', 'kerak', 'telor', 'toge', 'goreng', 'asinan', 'buah', 'asinan', 'sayur', 'bika', 'ambon', 'sebagainya', 'stan', 'nomor', 'beberapa', 'antaranya', 'dibubuhi', 'identitas', 'kuliner', 'provinsi', 'indonesia', 'nusa', 'tenggara', 'sumatera', 'utara', 'kalimantan', 'selatan', 'riau', 'sulawesi', 'barat', 'lainlain', 'stan', 'tersebut', 'merupakan', 'binaan', 'oce', 'terdiri', '14', 'stan', 'salah', 'satunya', 'stan', 'provinsi', 'berisi', 'makanan', 'semua', 'kuliner', 'dijual', 'stan', 'sesuai', 'id
# ...

# %% [markdown]
# ## 13. Add Custom Stopword ##
# Menambahkan kata di _stopword_ untuk dihilangkan pada sebuah teks.

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
from nltk.tokenize import word_tokenize 
    
# ambil stopword bawaan
stop_factory = StopWordRemoverFactory().get_stop_words()
more_stopword = ['daring', 'online']

kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."
kalimat = kalimat.translate(str.maketrans('','',string.punctuation)).lower()

# menggabungkan stopword
data = stop_factory + more_stopword

dictionary = ArrayDictionary(data)
str = StopWordRemover(dictionary)
tokens = nltk.tokenize.word_tokenize(str.remove(kalimat))
 
print(tokens)
# Out:
# ['jalan', 'mh', 'thamrin', 'malam', 'dipadati', 'pengunjung', 'pedagang', 'antara', 'pedagang', 'berjajar', 'mengais', 'rezeki', 'malam', 'tahun', 'baru', 'stan', 'okoce', 'berjajar', 'jalanannya', 'pantauan', 'detikcom', 'lokasi', 'jalan', 'mh', 'thamrin', 'jakarta', 'pusat', 'minggu', '31122017', 'stanstan', 'diketahui', 'sejak', 'sore', 'tadi', 'bertenda', 'putih', 'ratusan', 'pedagang', 'berderet', 'menjajakan', 'dagangan', 'dalamnya', 'seluruhnya', 'kuliner', 'pempek', 'sosis', 'bakar', 'kerak', 'telor', 'toge', 'goreng', 'asinan', 'buah', 'asinan', 'sayur', 'bika', 'ambon', 'sebagainya', 'stan', 'nomor', 'beberapa', 'antaranya', 'dibubuhi', 'identitas', 'kuliner', 'provinsi', 'indonesia', 'nusa', 'tenggara', 'sumatera', 'utara', 'kalimantan', 'selatan', 'riau', 'sulawesi', 'barat', 'lainlain', 'stan', 'tersebut', 'merupakan', 'binaan', 'oce', 'terdiri', '14', 'stan', 'salah', 'satunya', 'stan', 'provinsi', 'berisi', 'makanan', 'semua', 'kuliner', 'dijual', 'stan', 'sesuai', 'id
# ...

# %% [markdown]
# ## 14. Stemming : Porter Stemming Algorithm using NLTK ##
#
# https://tartarus.org/martin/PorterStemmer/index-old.html

# %%
from nltk.stem import PorterStemmer    
ps = PorterStemmer() 

kata = ["program", "programs", "programer", "programing", "programers"]

for k in kata:
    print(k, " : ", ps.stem(k))
# Out:
# program  :  program
# programs  :  program
# programer  :  program
# programing  :  program
# programers  :  program

# %% [markdown]
# ## 15. Stemming Bahasa Indonesia using Sastrawi ##

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
 
kalimat = "Jalan MH Thamrin malam ini dipadati pengunjung dan pedagang. Di antara pedagang yang berjajar mengais rezeki di malam tahun baru, ada stan OK-OCE yang berjajar di jalanannya. Pantauan detikcom di lokasi, Jalan MH Thamrin, Jakarta Pusat, Minggu (31/12/2017), stan-stan diketahui sudah ada sejak sore tadi. Bertenda putih, ada ratusan pedagang berderet menjajakan dagangan di dalamnya, yang seluruhnya adalah kuliner. Ada pempek, sosis bakar, kerak telor, toge goreng, asinan buah, asinan sayur, bika Ambon, dan sebagainya. Di stan ini ada nomor, dan beberapa di antaranya dibubuhi identitas kuliner provinsi di Indonesia, seperti Nusa Tenggara, Sumatera Utara, Kalimantan Selatan, Riau, Sulawesi Barat, dan lain-lain. Stan tersebut merupakan binaan OK OCE, dan terdiri dari 14 stan. Salah satunya stan Provinsi yang berisi makanan. Namun, tidak semua kuliner yang dijual dalam stan ini sesuai dengan identitas nama provinsi. Seperti Bir Pletok Hj Amilati yang dijual di stan Provinsi Maluku. Minuman khas Betawi ini terpaksa dijual di stan berbeda karena Amilati mengaku tidak kebagian stan asal kuliner DKI Jakarta. \"Soalnya saya nggak kebagian nomornya. Sudah penuh. Jadi ngisi yang Maluku. Saya sendiri coach wirausaha OK OCE, Megang Kecamatan Pancoran,\" ucap Amilati saat ditemui di lokasi. Ada pula gabungan komunitas pedagang dari Jaringan Wirausaha OK OCE Tebet yang berjualan di stan Sulawesi Tenggara dan Sulawesi Barat. Mereka mengaku sudah wira-wiri di berbagai acara dari Pemprov DKI Jakarta. \"Untuk acara seperti ini kita sudah dikontak, jadi kalau Pemprov ada acara bazar atau pameran, kita dikasih tahu. Alhamdulillah omzet hari ini paling banyak. Tapi saya belum hitung berapa,\" ucap Indri yang mengaku coach OK OCE dari Tebet. Namun, dia berkata setidaknya seorang pengunjung menghabiskan Rp 50 ribu untuk membeli makanan. Hingga kini ratusan orang sudah mampir ke stan ini. \"Harapan saya sih Rp 50 juta bisa dapat ya. Tapi masih belum tau. Namanya juga harapan ya,\" tuturnya. Jalan MH Thamrin ini sudah ditutup dari arus lalu lintas kendaraan sejak sore tadi. Namun, hingga kini masih ada bus TransJakarta yang melintas."

hasil = stemmer.stem(kalimat)

hasil
# Out:
# 'jalan mh thamrin malam ini padat unjung dan dagang di antara dagang yang jajar kais rezeki di malam tahun baru ada stan ok-oce yang jajar di jalan pantau detikcom di lokasi jalan mh thamrin jakarta pusat minggu 31 12 2017 stan tahu sudah ada sejak sore tadi tenda putih ada ratus dagang deret jaja dagang di dalam yang seluruh adalah kuliner ada pempek sosis bakar kerak telor toge goreng asin buah asin sayur bika ambon dan bagai di stan ini ada nomor dan beberapa di antara bubuh identitas kuliner provinsi di indonesia seperti nusa tenggara sumatera utara kalimantan selatan riau sulawesi barat dan lain stan sebut rupa bina ok oce dan diri dari 14 stan salah satu stan provinsi yang isi makan namun tidak semua kuliner yang jual dalam stan ini sesuai dengan identitas nama provinsi seperti bir pletok hj amilati yang jual di stan provinsi malu minum khas betawi ini paksa jual di stan beda karena amilati aku tidak bagi stan asal kuliner dki jakarta soal saya nggak bagi nomor sudah penuh jadi
# ...
